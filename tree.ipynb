# %%
#Binary Search Tree
class BST:
    def __init__(self,key):
        self.key=key
        self.lchild=None
        self.rchild=None

root=BST(10)
root.lchild=BST(5)

print(root.key)
print(root.lchild)
print(root.rchild)
print(root.lchild.key)
print(root.lchild.lchild)
print(root.lchild.rchild)
# Out:
# 10
# <__main__.BST object at 0x000002939E106350>
# None
# 5
# None
# None

# %%
class BST:
    def __init__(self,key):
        self.key =key 
        self.lchild=None
        self.rchild=None

    def insertBST(self,data):
        if self.key is None:
            self.key=data
            return
        # if self.key==data:#to avoid duplicate. Otherwise it will inserted to left or right subtree
        #     return
        if self.key>data:
            if self.lchild:
                self.lchild.insertBST(data)
            else:
                self.lchild=BST(data)
        else:
            if self.rchild:
                self.rchild.insertBST(data)
            else:
                self.rchild=BST(data)

    def search(self,data):
        if self.key==data:
            print("node is found..")
            return
        if data<self.key:
            if self.lchild:
                self.lchild.search(data)
            else:
                print("node is not present in tree")
        else:
            if self.rchild:
                self.rchild.search(data)
            else:
                print("node is not present in tree")

    def preorder(self):
        print(self.key,end=" ")
        if self.lchild:
            self.lchild.preorder()
        if self.rchild:
            self.rchild.preorder()
    
    def inorder(self):
        if self.lchild:
            self.lchild.inorder()
        print(self.key,end=" ")
        if self.rchild:
            self.rchild.inorder()

    def postorder(self):
        if self.lchild:
            self.lchild.postorder()
        if self.rchild:
            self.rchild.postorder()
        print(self.key,end=" ")

    def delete(self,data):
        if self.key==None:
            print("Tree is empty")
            return
        if data<self.key:
            if self.lchild:
                self.lchild=self.lchild.delete(data)
            else:
                print("given node is not present")
        elif data>self.key:
            if self.rchild:
                self.rchild=self.rchild.delete(data)
            else:
                print("given node is not present")
        else :
            if self.lchild is None:
                temp=self.rchild
                self=None
                return temp
            if self.rchild is None:
                temp=self.lchild
                self=None
                return temp
            #now we are finding smallest key in right subtree.to delete node with two child node
            node=self.rchild
            while node.lchild:
                node=node.lchild
            self.key=node.key
            self.rchild=self.rchild.delete(node.key)
        return self
            
        
        



root=BST(21)
list=[10,30,5,3,3,12,25,100,3,7]
for i in list:
    root.insertBST(i)

# root.search(5)
print("preorder traversal")
root.preorder()
# print("\ninorder traversal")
# root.inorder()
# print("\npostorder traversal")
# root.postorder()

root.delete(12)
print()
root.preorder()
# Out:
# preorder traversal
# 21 10 5 3 3 3 7 12 30 25 100
# 21 10 5 3 3 3 7 30 25 100

# %%
#deleting root node
class BST:
    def __init__(self,key):
        self.key =key 
        self.lchild=None
        self.rchild=None

    def insertBST(self,data):
        if self.key is None:
            self.key=data
            return
        if self.key==data:#to avoid duplicate. Otherwise it will inserted to left or right subtree
            return
        if self.key>data:
            if self.lchild:
                self.lchild.insertBST(data)
            else:
                self.lchild=BST(data)
        else:
            if self.rchild:
                self.rchild.insertBST(data)
            else:
                self.rchild=BST(data)


    def preorder(self):
        print(self.key,end=" ")
        if self.lchild:
            self.lchild.preorder()
        if self.rchild:
            self.rchild.preorder()
    

    def delete(self,data,curr):
        if self.key==None:
            print("Tree is empty")
            return
        if data<self.key:
            if self.lchild:
                self.lchild=self.lchild.delete(data,curr)
            else:
                print("given node is not present")
        elif data>self.key:
            if self.rchild:
                self.rchild=self.rchild.delete(data,curr)
            else:
                print("given node is not present")
        else :
            if self.lchild is None:
                temp=self.rchild
                if data==curr:
                    self.key=temp.key
                    self.lchild=temp.lchild
                    self.rchild=temp.rchild
                    temp=None
                    return
                self=None
                return temp
            if self.rchild is None:
                temp=self.lchild
                if data==curr:
                    self.key=temp.key
                    self.lchild=temp.lchild
                    self.rchild=temp.rchild
                    temp=None
                    return
                self=None
                return temp
            #now we are finding smallest key in right subtree.to delete node with two child node
            node=self.rchild
            while node.lchild:
                node=node.lchild
            self.key=node.key
            self.rchild=self.rchild.delete(node.key,curr)
        return self
            
        
        
def count(node):
    if node is None:
        return 0
    return 1+count(node.lchild)+count(node.rchild)


root=BST(21)
list=[22,23]
for i in list:
    root.insertBST(i)

print("number of nodes :",count(root))

print("preorder traversal")
root.preorder()

if count(root)>1:
    root.delete(21,root.key)#here root.key is given to identify whether we are deleting rootnode
else:
    print("\ndeletion not possible ")

print()
root.preorder()
# Out:
# number of nodes : 3
# preorder traversal
# 21 22 23
# 22 23

# %%
class BST:
    def __init__(self,key):
        self.key =key 
        self.lchild=None
        self.rchild=None

    def insertBST(self,data):
        if self.key is None:
            self.key=data
            return
        if self.key==data:#to avoid duplicate. Otherwise it will inserted to left or right subtree
            return
        if self.key>data:
            if self.lchild:
                self.lchild.insertBST(data)
            else:
                self.lchild=BST(data)
        else:
            if self.rchild:
                self.rchild.insertBST(data)
            else:
                self.rchild=BST(data)


    def preorder(self):
        print(self.key,end=" ")
        if self.lchild:
            self.lchild.preorder()
        if self.rchild:
            self.rchild.preorder()

    def min_node(self):
        current=self
        while current.lchild:
            current=current.lchild
        print("node with minimum value is  ",current.key)

    def max_node(self):
        current=self
        while current.rchild:
            current=current.rchild
        print("node with maximum value ",current.key)

root=BST(21)
list=[10,5,4,22,25,100]
for i in list:
    root.insertBST(i)  

print("preorder traversal")
root.preorder()
print()
root.min_node()
root.max_node()
# Out:
# preorder traversal
# 21 10 5 4 22 25 100
# node with minimum value is   4
# node with maximum value  100

# %%
import heapq#follow min heap property  
heap=[]
heapq.heappush(heap,10)
heap
# Out:
# [10]

# %%
heapq.heappush(heap,20)
heapq.heappush(heap,1)
heap
# Out:
# [1, 20, 10]

# %%
heapq.heappop(heap)
# Out:
# 1

# %%
heap
# Out:
# [10, 20]

# %%
list=[1,3,5,2,4,6]
heapq.heapify(list)
list
# Out:
# [1, 2, 5, 3, 4, 6]

# %%
heapq.heappushpop(list,98)
list
# Out:
# [2, 3, 5, 98, 4, 6]

# %%
heapq.heapreplace(heap,100)
# Out:
# 10

# %%
heap
# Out:
# [20, 100]

# %%
heapq.nsmallest(2,list)
# Out:
# [2, 3]

# %%
heapq.nlargest(3,list)
# Out:
# [98, 6, 5]

# %%
#priority queue 
list1=[(1,"ria"),(4,"sia"),(3,"gia")]
heapq.heapify(list1)
print(list1)

for i in range (len(list1)):
    print(heapq.heappop(list1))
# Out:
# [(1, 'ria'), (4, 'sia'), (3, 'gia')]
# (1, 'ria')
# (3, 'gia')
# (4, 'sia')

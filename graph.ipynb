# %%
#Function to add  a node using adjacency matrix representation
def add_node(v):
    global node_count
    if v in node:
        print(v,"is already present in graph")
    else:
        node_count+=1
        node.append(v)#add node name to node list
        for n in graph:#n is the row
            n.append(0)#we are adding 0 to each row ie we are adding a new column 
             #now we need to add a new row with 0 in it
              #every row is a list
        temp=[]
        for i in range (node_count):
            temp.append(0)
        graph.append(temp)




node=[]#to store nodes of graph
graph=[]#to store adjacency matrix
node_count=0
add_node('A')
add_node('B')
print(node)
print(graph)
# Out:
# ['A', 'B']
# [[0, 0], [0, 0]]

# %%
#function to add edge between nodes using adjacensy matrix
def add_edge(v1,v2):#function for undirected unweighted graph
    if v1 not in node:
         print(v1,"is not present in the graph")
    elif v2 not in node:
        print(v2,"is not present in the graph") 
    else:
        index1=node.index(v1)
        index2=node.index(v2)
        graph[index1][index2]=1
        graph[index2][index1]=1 

def add_node(v):
    global node_count
    if v in node:
        print(v,"is already present in graph")
    else:
        node_count+=1
        node.append(v)
        for n in graph :
            n.append(0)
        temp=[]
        for i in range(node_count):
            temp.append(0)
        graph.append(temp)
node=[]
node_count=0
graph=[]
add_node('A')
add_node('B')
add_node("D")
add_edge('A','B')
print(node)
print(graph)
# Out:
# ['A', 'B', 'D']
# [[0, 1, 0], [1, 0, 0], [0, 0, 0]]

# %%
#function to add edge between nodes using adjacensy matrix
def add_edge(v1,v2,weight):#function for undirected weighted graph
    if v1 not in node:
         print(v1,"is not present in the graph")
    elif v2 not in node:
        print(v2,"is not present in the graph") 
    else:
        index1=node.index(v1)
        index2=node.index(v2)
        graph[index1][index2]=weight
        #graph[index2][index1]=weight#don't give this for directed graph if edge from v1 to v2

def add_node(v):
    global node_count
    if v in node:
        print(v,"is already present in graph")
    else:
        node_count+=1
        node.append(v)
        for n in graph :
            n.append(0)
        temp=[]
        for i in range(node_count):
            temp.append(0)
        graph.append(temp)

def print_graph():
    for i in range(node_count):
        for j in range(node_count):
            print(graph[i][j],end="  ")
        print()
node=[]
node_count=0
graph=[]
add_node('A')
add_node('B')
add_node("D")
add_edge('A','B',8)
add_edge('B','D',10)
print(node)
print(graph)
print_graph()
# Out:
# ['A', 'B', 'D']
# [[0, 8, 0], [0, 0, 10], [0, 0, 0]]
# 0  8  0
# 0  0  10
# 0  0  0

# %% [markdown]
# function to add a new node and edge using adjacency list representation

# %%
def add_node(v):
    if v in graph:
        print(v,"is already present in the graph")
    else:
        graph[v]=[]

def add_edge(v1,v2):#unweighted undirected graph
    if v1 not in graph:
        print(v1,"not present in graph")
    elif v2 not in graph:
        print(v2,"not present in graph")   
    else:
        graph[v1].append(v2)
        graph[v2].append(v1)#for directed graph avoid this if direction from v1 to v2
graph={}
add_node('A')
add_node('B')
add_node('C')
add_edge('A','B')
print(graph)
# Out:
# {'A': ['B'], 'B': ['A'], 'C': []}

# %%
def add_node(v):
    if v in graph:
        print(v,"is already present in the graph")
    else:
        graph[v]=[]

def add_edge(v1,v2,weight):#weighted undirected graph
    if v1 not in graph:
        print(v1,"not present in graph")
    elif v2 not in graph:
        print(v2,"not present in graph")   
    else:
        list1=[v2,weight]
        list2=[v1,weight]
        graph[v1].append(list1)
        graph[v2].append(list2)
graph={}
add_node('A')
add_node('B')
add_node('C')
add_edge('A','B',10)
print(graph)
# Out:
# {'A': [['B', 10]], 'B': [['A', 10]], 'C': []}

# %% [markdown]
# Deletion operation

# %%
#Function to delete a node and edge using adjacency matrix representation

def add_edge(v1,v2):
    if v1 not in node:
         print(v1,"is not present in the graph")
    elif v2 not in node:
        print(v2,"is not present in the graph") 
    else:
        index1=node.index(v1)
        index2=node.index(v2)
        graph[index1][index2]=1
        graph[index2][index1]=1 

def add_node(v):
    global node_count
    if v in node:
        print(v,"is already present in graph")
    else:
        node_count+=1
        node.append(v)
        for n in graph :
            n.append(0)
        temp=[]
        for i in range(node_count):
            temp.append(0)
        graph.append(temp)

def delete_node(v):
    global node_count
    if v not in node:
        print(v,"is not present in the graph")
    else:
        indexv=node.index(v)
        node.remove(v)
        node_count-=1

        graph.pop(indexv)#delete the vth row
        #to delete vth column from each row
        for i in graph:
            i.pop(indexv)

#Function to delete edge undirected graph WEighted/unweighted 
def delete_edge(v1,v2):
    if v1 not in node:
        print(v1,"is not present in graph")
    elif v2 not in node:
        print(v2,"is not present in graph")
    else:
        index1=node.index(v1)
        index2=node.index(v2)
        graph[index1][index2]=0
        graph[index2][index1]=0#not use this for directed graph

    

node=[]
node_count=0
graph=[]
add_node('A')
add_node('B')
add_node("D")
add_edge('A','B')
print(node)
print(graph)

delete_edge('A','B')
print(node)

print(graph)
# Out:
# ['A', 'B', 'D']
# [[0, 1, 0], [1, 0, 0], [0, 0, 0]]
# ['A', 'B', 'D']
# [[0, 0, 0], [0, 0, 0], [0, 0, 0]]

# %% [markdown]
# Function to delete a node and edge using adjacency list representation

# %%
def add_node(v):
    if v in graph:
        print(v,"is already present in the graph")
    else:
        graph[v]=[]

def add_edge(v1,v2):#unweighted undirected graph
    if v1 not in graph:
        print(v1,"not present in graph")
    elif v2 not in graph:
        print(v2,"not present in graph")   
    else:
        graph[v1].append(v2)
        graph[v2].append(v1)#for directed graph avoid this if direction from v1 to v2

def delete_node(v):
    if v not in graph:
        print(v,"is not present in the graph")
    else:
        graph.pop(v)
        for i in graph:
            list1=graph[i]
            if v in list1:
                list1.remove(v)

def delete_edge(v1,v2):
    if v1 not in graph:
        print(v1,"is not in graph")
    elif v2 not in graph:
        print(v2,"is not in graph")
    else:
        if v2 in graph[v1]:
            graph[v1].remove(v2)
            graph[v2].remove(v1)

graph={}
add_node('A')
add_node('B')
add_node('C')
add_node('D')
add_node('E')
add_edge('A','B')
add_edge('B','E')
add_edge('A','C')
add_edge('A','D')
add_edge('B','D')
add_edge('C','D')
add_edge('D','E')
print(graph)
delete_edge('C','D')
# delete_node('C')
# delete_node('B')
print(graph)
# Out:
# {'A': ['B', 'C', 'D'], 'B': ['A', 'E', 'D'], 'C': ['A', 'D'], 'D': ['A', 'B', 'C', 'E'], 'E': ['B', 'D']}
# {'A': ['B', 'C', 'D'], 'B': ['A', 'E', 'D'], 'C': ['A'], 'D': ['A', 'B', 'E'], 'E': ['B', 'D']}

# %%
#weighted
def add_node(v):
    if v in graph:
        print(v,"is already present in the graph")
    else:
        graph[v]=[]

def add_edge(v1,v2,weight):#weighted undirected graph
    if v1 not in graph:
        print(v1,"not present in graph")
    elif v2 not in graph:
        print(v2,"not present in graph")   
    else:
        list1=[v2,weight]
        list2=[v1,weight]
        graph[v1].append(list1)
        graph[v2].append(list2)

def delete_node(v):
    if v not in graph:
        print(v,"is not present in the graph")
    else:
        graph.pop(v)
        for i in graph:
            list1=graph[i]
            for j  in list1:
                if v==j[0]:
                    list1.remove(j)
                    break

def delete_edge(v1,v2,weight):
    if v1 not in graph:
        print(v1,"is not in graph")
    elif v2 not in graph:
        print(v2,"is not in graph")
    else:
        temp=[v1,weight]
        temp1=[v2,weight]
        if temp1 in graph[v1]:
            graph[v1].remove(temp1)
            graph[v2].remove(temp)

graph={}
add_node('A')
add_node('B')
add_node('C')
add_node('D')
add_node('E')
add_edge('A','B',10)
add_edge('B','E',3)
add_edge('A','C',5)
add_edge('A','D',4)
add_edge('B','D',7)
add_edge('C','D',1)
add_edge('D','E',2)
print(graph)
# delete_node('C')
delete_edge('C','D',1)
print(graph)
# Out:
# {'A': [['B', 10], ['C', 5], ['D', 4]], 'B': [['A', 10], ['E', 3], ['D', 7]], 'C': [['A', 5], ['D', 1]], 'D': [['A', 4], ['B', 7], ['C', 1], ['E', 2]], 'E': [['B', 3], ['D', 2]]}
# {'A': [['B', 10], ['C', 5], ['D', 4]], 'B': [['A', 10], ['E', 3], ['D', 7]], 'C': [['A', 5]], 'D': [['A', 4], ['B', 7], ['E', 2]], 'E': [['B', 3], ['D', 2]]}

# %% [markdown]
# DFS using recursion

# %%
def add_node(v):
    if v in graph:
        print(v,'is already in graph')
    else:
        graph[v]=[]
def add_edge(v1,v2):
    if v1 not in graph:
        print(v1,'is not in graph')
    elif v2 not in graph:
        print(v2,'is not in graph')
    else:
        graph[v1].append(v2)
        graph[v2].append(v1)

def DFS(node,visited,graph):#node is the starting node
    if node not in graph:
        print(node,'not in graph')
        return 
    if node not in visited:
        print(node)
        visited.add(node)
        for i in graph[node]:#for each adjacent node of node
            DFS(i,visited,graph)



visited=set()
graph={}
add_node('A')
add_node('B')
add_node('C')
add_node('D')
add_node('E')
add_edge('A','B')
add_edge('B','E')
add_edge('A','C')
add_edge('A','D')
add_edge('B','D')
add_edge('C','D')
add_edge('D','E')
print(graph)
DFS('B',visited,graph)
# Out:
# {'A': ['B', 'C', 'D'], 'B': ['A', 'E', 'D'], 'C': ['A', 'D'], 'D': ['A', 'B', 'C', 'E'], 'E': ['B', 'D']}
# B
# A
# C
# D
# E

# %%
#WEIGHTED GRAPH
def add_node(v):
    if v in graph:
        print(v,"is already present in the graph")
    else:
        graph[v]=[]

def add_edge(v1,v2,weight):#weighted undirected graph
    if v1 not in graph:
        print(v1,"not present in graph")
    elif v2 not in graph:
        print(v2,"not present in graph")   
    else:
        list1=[v2,weight]
        list2=[v1,weight]
        graph[v1].append(list1)
        graph[v2].append(list2)

def DFS(node,visited,graph):
    if node not in graph:
        print(node,'not in graph')
        return
    if node not in visited:
        print(node)
        visited.add(node)
        for i in graph[node]:
            DFS(i[0],visited,graph)

visited=set()
graph={}
add_node('A')
add_node('B')
add_node('C')
add_edge('A','B',10)
add_edge('A','C',3)
print(graph)
DFS('A',visited,graph)
# Out:
# {'A': [['B', 10], ['C', 3]], 'B': [['A', 10]], 'C': [['A', 3]]}
# A
# B
# C

# %% [markdown]
# DFS using Iteration

# %%
def add_node(v):
    if v in graph:
        print(v,'is already in graph')
    else:
        graph[v]=[]
def add_edge(v1,v2):
    if v1 not in graph:
        print(v1,'is not in graph')
    elif v2 not in graph:
        print(v2,'is not in graph')
    else:
        graph[v1].append(v2)
        graph[v2].append(v1)

def DFSiterative(node,garph):
    visited=set()
    if node not in graph:
        print(node,'not present in graph')
        return
    stack=[]
    stack.append(node)
    while stack:
        current=stack.pop()
        if current not in visited:
            print(current)
            visited.add(current)
            for i in graph[current]:
                stack.append(i)

graph={}
add_node('A')
add_node('B')
add_node('C')
add_node('D')
add_node('E')
add_edge('A','B')
add_edge('B','E')
add_edge('A','C')
add_edge('A','D')
add_edge('B','D')
add_edge('C','D')
add_edge('D','E')
print(graph)
DFSiterative('A',graph)
# Out:
# {'A': ['B', 'C', 'D'], 'B': ['A', 'E', 'D'], 'C': ['A', 'D'], 'D': ['A', 'B', 'C', 'E'], 'E': ['B', 'D']}
# A
# D
# E
# B
# C

# %% [markdown]
# Using DFS to check whether graph is connected or disconnected graph

# %%
def add_node(v):
    if v in graph:
        print(v,'is already in graph')
    else:
        graph[v]=[]
def add_edge(v1,v2):
    if v1 not in graph:
        print(v1,'is not in graph')
    elif v2 not in graph:
        print(v2,'is not in graph')
    else:
        graph[v1].append(v2)
        graph[v2].append(v1)

def DFS(node,visited,graph):#node is the starting node
    if node not in graph:
        print(node,'not in graph')
        return 
    if node not in visited:
        print(node)
        visited.add(node)
        for i in graph[node]:#for each adjacent node of node
            DFS(i,visited,graph)



visited=set()
graph={}
add_node('A')
add_node('B')
add_node('C')
add_node('D')
add_node('E')
add_node('F')
add_node('G')
add_edge('A','B')
add_edge('A','C')
add_edge('C','D')
add_edge('B','C')
add_edge('E','F')
add_edge('E','G')
print(graph)
DFS('B',visited,graph)

for i in list(graph):
    if i not in visited:
        print("given graph is disconnected graph")
        break
else:#will not work if loop is stopped by break
    print("graph is connected graph")
# Out:
# {'A': ['B', 'C'], 'B': ['A', 'C'], 'C': ['A', 'D', 'B'], 'D': ['C'], 'E': ['F', 'G'], 'F': ['E'], 'G': ['E']}
# B
# A
# C
# D
# given graph is disconnected graph

# %% [markdown]
# HOW TO TRAVERSE THROUGH DISCONNECTED GRAPH USING DFS

# %%
def add_node(v):
    if v in graph:
        print(v,'is already in graph')
    else:
        graph[v]=[]
def add_edge(v1,v2):
    if v1 not in graph:
        print(v1,'is not in graph')
    elif v2 not in graph:
        print(v2,'is not in graph')
    else:
        graph[v1].append(v2)
        graph[v2].append(v1)

def DFS(node,visited,graph):#node is the starting node
    if node not in graph:
        print(node,'not in graph')
        return 
    if node not in visited:
        print(node)
        visited.add(node)
        for i in graph[node]:#for each adjacent node of node
            DFS(i,visited,graph)



visited=set()
graph={}
add_node('A')
add_node('B')
add_node('C')
add_node('D')
add_node('E')
add_node('F')
add_node('G')
add_edge('A','B')
add_edge('A','C')
add_edge('C','D')
add_edge('B','C')
add_edge('E','F')
add_edge('E','G')
print(graph)
DFS('B',visited,graph)

for i in list(graph):
    if i not in visited:
        print("next connected component")
        DFS(i,visited,graph)
# Out:
# {'A': ['B', 'C'], 'B': ['A', 'C'], 'C': ['A', 'D', 'B'], 'D': ['C'], 'E': ['F', 'G'], 'F': ['E'], 'G': ['E']}
# B
# A
# C
# D
# next connected component
# E
# F
# G

# %% [markdown]
# HOW TO CHECK A GRAPH IS STRONGLY CONNECTED OR WEAKLY CONNECTED USING DFS (directed graph)

# %%
def add_node(v):
    if v in graph:
        print(v,'is already in graph')
    else:
        graph[v]=[]
        graphreverse[v]=[]
def add_edge(v1,v2):
    if v1 not in graph:
        print(v1,'is not in graph')
    elif v2 not in graph:
        print(v2,'is not in graph')
    else:
        graph[v1].append(v2)
        graphreverse[v2].append(v1)
       

def DFS(node,visited,graph):
    if node not in graph:
        print(node,'not in graph')
        return 
    if node not in visited:
        print(node)
        visited.add(node)
        for i in graph[node]:
            DFS(i,visited,graph)
visited=set()           
graph={}
graphreverse={}
visitedreverse=set()

#weak graph
add_node('A')
add_node('B')
add_node('C')
add_node('D')
add_node('E')
add_edge('A','B')
add_edge('B','E')
add_edge('A','C')
add_edge('A','D')
add_edge('B','D')
add_edge('C','D')
add_edge('D','E')

#strong graph

# add_node('A')
# add_node('B')
# add_node('C')
# add_node('D')
# add_edge('A','B')
# add_edge('C','A')
# add_edge('B','D')
# add_edge('B','C')
# add_edge('D','C')

print(graph)
DFS('D',visited,graph)
for i in list(graph):
    if i not in visited:
        print("weakly connected graph")
        break
else:
    DFS('D',visitedreverse,graphreverse)
    if visited==visitedreverse:
        print("strongly connected graph")
    else:
        print("weakly connected")
# Out:
# {'A': ['B', 'C', 'D'], 'B': ['E', 'D'], 'C': ['D'], 'D': ['E'], 'E': []}
# D
# E
# weakly connected graph

# %% [markdown]
# TRAVERSING WEAKLY CONNECTED GRAPH

# %%
def add_node(v):
    if v in graph:
        print(v,'is already in graph')
    else:
        graph[v]=[]
        
def add_edge(v1,v2):
    if v1 not in graph:
        print(v1,'is not in graph')
    elif v2 not in graph:
        print(v2,'is not in graph')
    else:
        graph[v1].append(v2)
      
       

def DFS(node,visited,graph):
    if node not in graph:
        print(node,'not in graph')
        return 
    if node not in visited:
        print(node)
        visited.add(node)
        for i in graph[node]:
            DFS(i,visited,graph)
visited=set()           
graph={}


#weak graph
add_node('A')
add_node('B')
add_node('C')
add_node('D')
add_node('E')
add_edge('A','B')
add_edge('B','E')
add_edge('A','C')
add_edge('A','D')
add_edge('B','D')
add_edge('C','D')
add_edge('D','E')

#strong graph

# add_node('A')
# add_node('B')
# add_node('C')
# add_node('D')
# add_edge('A','B')
# add_edge('C','A')
# add_edge('B','D')
# add_edge('B','C')
# add_edge('D','C')

print(graph)
DFS('D',visited,graph)
for i in list(graph):
    if i not in visited:
       DFS(i,visited,graph)
# Out:
# {'A': ['B', 'C', 'D'], 'B': ['E', 'D'], 'C': ['D'], 'D': ['E'], 'E': []}
# D
# E
# A
# B
# C

# %% [markdown]
# BFS

# %%
def add_node(v):
    if v in graph:
        print(v,'is already in graph')
    else:
        graph[v]=[]

def add_edge(v1,v2):
    if v1 not in graph:
        print(v1,'is not in graph')
    elif v2 not in graph:
        print(v2,'is not in graph')
    else:
        graph[v1].append(v2)
        graph[v2].append(v1)

def BFS(node,graph,visited1):
    if  node not in graph:
        print(node,'not in graph')
        return
    
    queue=[]
    queue.append(node)
    visited1.add(node)
    while queue:
        current=queue.pop(0)
        print(current)
        for i in graph[current]:
            if i not in visited1:
                queue.append(i)
                visited1.add(i)





visited1=set()
graph={}
add_node('A')
add_node('B')
add_node('C')
add_node('D')
add_node('E')
add_node('F')
add_edge('A','B')
add_edge('B','D')
add_edge('A','C')
add_edge('C','D')
add_edge('B','E')
add_edge('E','D')
add_edge('D','F')
print(graph)
BFS('A',graph,visited1)
# Out:
# {'A': ['B', 'C'], 'B': ['A', 'D', 'E'], 'C': ['A', 'D'], 'D': ['B', 'C', 'E', 'F'], 'E': ['B', 'D'], 'F': ['D']}
# A
# B
# C
# D
# E
# F

# %% [markdown]
# BFS to check whether graph is connected or disconnected

# %%
def add_node(v):
    if v in graph:
        print(v,'is already in graph')
    else:
        graph[v]=[]

def add_edge(v1,v2):
    if v1 not in graph:
        print(v1,'is not in graph')
    elif v2 not in graph:
        print(v2,'is not in graph')
    else:
        graph[v1].append(v2)
        graph[v2].append(v1)

def BFS(node,graph,visited1):
    if  node not in graph:
        print(node,'not in graph')
        return
    
    queue=[]
    queue.append(node)
    visited1.add(node)
    while queue:
        current=queue.pop(0)
        print(current)
        for i in graph[current]:
            if i not in visited1:
                queue.append(i)
                visited1.add(i)





visited1=set()
graph={}
add_node('A')
add_node('B')
add_node('C')
add_node('D')
add_node('E')
add_node('F')
add_node('G')
add_edge('A','B')
add_edge('B','D')
add_edge('A','C')
add_edge('C','D')

add_edge('F','E')
add_edge('F','G')
print(graph)
BFS('A',graph,visited1)

for i in list(graph):
    if i not in visited1:
        print("graph is disconnected")
        break
else:
    print("given graph is connected")
# Out:
# {'A': ['B', 'C'], 'B': ['A', 'D'], 'C': ['A', 'D'], 'D': ['B', 'C'], 'E': ['F'], 'F': ['E', 'G'], 'G': ['F']}
# A
# B
# C
# D
# graph is disconnected

# %% [markdown]
# strongly connected or weakly connected

# %%
def add_node(v):
    if v in graph:
        print(v,'is already in graph')
    else:
        graph[v]=[]
        graph1[v]=[]

def add_edge(v1,v2):
    if v1 not in graph:
        print(v1,'is not in graph')
    elif v2 not in graph:
        print(v2,'is not in graph')
    else:
        graph[v1].append(v2)
        graph1[v2].append(v1)

def BFS(node,graph,visited1):
    if  node not in graph:
        print(node,'not in graph')
        return
    
    queue=[]
    queue.append(node)
    visited1.add(node)
    while queue:
        current=queue.pop(0)
        print(current)
        for i in graph[current]:
            if i not in visited1:
                queue.append(i)
                visited1.add(i)





visited1=set()
visited2=set()
graph={}
graph1={}
add_node('A')
add_node('B')
add_node('C')
add_node('D')
add_node('E')
add_node('F')
add_node('G')
add_edge('A','B')
add_edge('B','E')
add_edge('A','C')
add_edge('A','D')
add_edge('C','F')
add_edge('C','D')
add_edge('D','E')
add_edge('E','F')
add_edge('E','G')
print(graph)
BFS('D',graph,visited1)
print()

for i in list(graph):
    if i not in visited1:
        print("graph is weakly connected")
        break
else:
    BFS('D',graph1,visited2)
    if visited2==visited1:
        print("strong")
    else:
        print("weakly")
# Out:
# {'A': ['B', 'C', 'D'], 'B': ['E'], 'C': ['F', 'D'], 'D': ['E'], 'E': ['F', 'G'], 'F': [], 'G': []}
# D
# E
# F
# G
#
# graph is weakly connected

# %% [markdown]
# SHORTEST PATH

# %%
from collections import deque
def add_node(v):
    if v in graph:
        print(v,"is already present in the graph")
    else:
        graph[v]=[]

def add_edge(v1,v2):#unweighted undirected graph
    if v1 not in graph:
        print(v1,"not present in graph")
    elif v2 not in graph:
        print(v2,"not present in graph")   
    else:
        graph[v1].append(v2)
        graph[v2].append(v1)#for directed graph avoid this if direction from v1 to v2

def shortestpath(graph,node,target):
    if node not in graph:
        print(node,"not in graph")
    elif target not in graph:
        print(target,"not in graph")
    else:
        visited={}#to store visited node and its parent
        queue=deque()
        visited[node]=None#starting node has no parent
        queue.append(node)
        while queue:
            current=queue.popleft()
            if current==target:
                path=[]
                while current:
                    path.append(current)
                    current=visited[current]
                return path[::-1]
            for i in graph[current]:
                if i not in visited:
                    visited[i]=current
                    queue.append(i)



graph={}
add_node('A')
add_node('B')
add_node('C')
add_node('D')
add_node('E')
add_node('F')
add_node('G')
add_node('H')
add_node('I')
add_edge('A','B')
add_edge('A','D')
add_edge('A','F')
add_edge('B','C')
add_edge('C','D')
add_edge('C','E')
add_edge('C','H')
add_edge('D','I')
add_edge('D','G')
add_edge('H','G')

print(graph)
result=shortestpath(graph,'A','G')
print("shortest path is ",result)
# Out:
# {'A': ['B', 'D', 'F'], 'B': ['A', 'C'], 'C': ['B', 'D', 'E', 'H'], 'D': ['A', 'C', 'I', 'G'], 'E': ['C'], 'F': ['A'], 'G': ['D', 'H'], 'H': ['C', 'G'], 'I': ['D']}
# shortest path is  ['A', 'D', 'G']

# %% [markdown]
# Detect cycle in undirected graph

# %%
def add_node(v):
    if v in graph:
        print(v,'is already in graph')
    else:
        graph[v]=[]

def add_edge(v1,v2):
    if v1 not in graph:
        print(v1,'is not in graph')
    elif v2 not in graph:
        print(v2,'is not in graph')
    else:
        graph[v1].append(v2)
        graph[v2].append(v1)

def BFS(node,graph,visited1):
    if  node not in graph:
        print(node,'not in graph')
        return
    
    queue=[]
    parent={node:None}
    queue.append(node)
    visited1.add(node)
    while queue:
        current=queue.pop(0)
        print(current)
        for i in graph[current]:
            if i not in visited1:
                parent[i]=current
                queue.append(i)
                visited1.add(i)
            elif parent[current]!=i:
                return True
    return False





visited1=set()
graph={}
add_node('A')
add_node('B')
add_node('C')
add_node('D')
add_node('E')

add_edge('A','B')
add_edge('B','C')
add_edge('D','E')
add_edge('C','D')
add_edge('D','A')

print(graph)
if BFS('A',graph,visited1):
    print("cycle is detected in the graph")
else:
    print("no cycle detected")
# Out:
# {'A': ['B', 'D'], 'B': ['A', 'C'], 'C': ['B', 'D'], 'D': ['E', 'C', 'A'], 'E': ['D']}
# A
# B
# D
# cycle is detected in the graph

# %% [markdown]
# DIJIKSTRA'S ALGORITHM

# %%
import heapq
def add_node(v):
    if v in graph:
        print(v,'already in graph')
    else:
        graph[v]=[]
    
def add_edge(v1,v2,cost):
    if v1 not in graph:
        print(v1,'not in graph')
    elif v2 not in graph:
        print(v2,"not in graph")
    else:
        graph[v1].append([v2,cost])
        graph[v2].append([v1,cost])

def dijikstras(graph,start):

    distance={item:float("inf")for item in graph}#it will assign inf to all node
    distance[start]=0#assign start node distance as 0
    queue=[(0,start)]#add first node to priority queue
    while queue:
        current_dist,current_node=heapq.heappop(queue)#return two value distance and node
        if current_dist>distance[current_node]:
            continue
        for node,weight  in graph[current_node]:
            new_distance=current_dist+weight
            if new_distance<distance[node]:
                distance[node]=new_distance
                heapq.heappush(queue,(new_distance,node))
    return distance

        


graph={}
add_node('A')
add_node('B')
add_node('C')
add_node('D')
add_node('E')
add_node('F')
add_node('G')
add_node('H')
add_node('I')
add_edge('A','B',1)
add_edge('A','D',4)
add_edge('A','F',7)
add_edge('B','C',3)
add_edge('C','D',5)
add_edge('C','E',4)
add_edge('C','H',5)
add_edge('D','I',3)
add_edge('D','G',2)
add_edge('H','G',1)
print(graph)
print(dijikstras(graph,'A'))
# Out:
# {'A': [['B', 1], ['D', 4], ['F', 7]], 'B': [['A', 1], ['C', 3]], 'C': [['B', 3], ['D', 5], ['E', 4], ['H', 5]], 'D': [['A', 4], ['C', 5], ['I', 3], ['G', 2]], 'E': [['C', 4]], 'F': [['A', 7]], 'G': [['D', 2], ['H', 1]], 'H': [['C', 5], ['G', 1]], 'I': [['D', 3]]}
# {'A': 0, 'B': 1, 'C': 4, 'D': 4, 'E': 8, 'F': 7, 'G': 6, 'H': 7, 'I': 7}

# %%
dic={'A': [['B', 1], ['D', 4], ['F', 7]], 'B': [['A', 1], ['C', 3]], 'C': [['B', 3], ['D', 5], ['E', 4], ['H', 5]], 'D': [['A', 4], ['C', 5], ['I', 3], ['G', 2]], 'E': [['C', 4]], 'F': [['A', 7]], 'G': [['D', 2], ['H', 1]], 'H': [['C', 5], ['G', 1]], 'I': [['D', 3]]}
distance={item:float('inf') for item in dic}
distance
# Out:
# {'A': inf,
#  'B': inf,
#  'C': inf,
#  'D': inf,
#  'E': inf,
#  'F': inf,
#  'G': inf,
#  'H': inf,
#  'I': inf}

# %%
import heapq
def add_node(v):
    if v in graph:
        print(v,'already in graph')
    else:
        graph[v]=[]
    
def add_edge(v1,v2,cost):
    if v1 not in graph:
        print(v1,'not in graph')
    elif v2 not in graph:
        print(v2,"not in graph")
    else:
        graph[v1].append([v2,cost])
        graph[v2].append([v1,cost])

def dijikstras(graph,start):

    distance={item:float("inf")for item in graph}#it will assign inf to all node
    distance[start]=0#assign start node distance as 0
    queue=[(0,start)]#add first node to priority queue
    previous={node:None for node in graph}#to store parent node of all node
    while queue:
        current_dist,current_node=heapq.heappop(queue)#return two value distance and node
        if current_dist>distance[current_node]:
            continue
        for node,weight  in graph[current_node]:
            new_distance=current_dist+weight
            if new_distance<distance[node]:
                distance[node]=new_distance
                previous[node]=current_node
                heapq.heappush(queue,(new_distance,node))
    return distance,previous

def shortest_path(parent_node,target):
    path=[]
    current=target 
    while current:
        path.append(current)
        current=parent_node[current]    
    return path[::-1]  


graph={}
add_node('A')
add_node('B')
add_node('C')
add_node('D')
add_node('E')
add_node('F')
add_node('G')
add_node('H')
add_node('I')
add_edge('A','B',1)
add_edge('A','D',4)
add_edge('A','F',7)
add_edge('B','C',3)
add_edge('C','D',5)
add_edge('C','E',4)
add_edge('C','H',5)
add_edge('D','I',3)
add_edge('D','G',2)
add_edge('H','G',1)
print(graph)
print(dijikstras(graph,'A'))

#to find shortest path use below code
source='A'
end='I'
if source not in graph:
    print(source,'not in graph')
elif end not in graph:
    print(end,'not in graph')
else:
    smallest_distance,parent_node=dijikstras(graph,source)
    print("shaortest distance",smallest_distance[end])
    print(shortest_path(parent_node,end))
# Out:
# {'A': [['B', 1], ['D', 4], ['F', 7]], 'B': [['A', 1], ['C', 3]], 'C': [['B', 3], ['D', 5], ['E', 4], ['H', 5]], 'D': [['A', 4], ['C', 5], ['I', 3], ['G', 2]], 'E': [['C', 4]], 'F': [['A', 7]], 'G': [['D', 2], ['H', 1]], 'H': [['C', 5], ['G', 1]], 'I': [['D', 3]]}
# ({'A': 0, 'B': 1, 'C': 4, 'D': 4, 'E': 8, 'F': 7, 'G': 6, 'H': 7, 'I': 7}, {'A': None, 'B': 'A', 'C': 'B', 'D': 'A', 'E': 'C', 'F': 'A', 'G': 'D', 'H': 'G', 'I': 'D'})
# shaortest distance 7
# ['A', 'D', 'I']
